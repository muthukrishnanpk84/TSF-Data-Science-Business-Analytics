# %% [markdown]
# ### Task-3 Prediction using Decision Tree Algorithm
# ### Submitted By - Muthu Krishnan

# %% [markdown]
# #### In this section with the given ‘Iris’ dataset, we are going to create the Decision Tree Classifier and show some visual representations for detail insights.

# %% [markdown]
# #### The task is to predict the right class with our Decision Tree classification model. We can also represent the classification graphically and check how it reaches the decision.

# %%
### Decision Tree is the simplest form of supervised multivariate classification model.

# %%
### Let's first import the required libraries from pandas,numpy,seaborn,matplotlib as well as modules from scikit-learn

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
iris=pd.read_csv(r'C:\Users\Lenovo\Desktop\GRIP Spark Foundation Internship\Task 3\Iris_set.csv')

# %%
### Dropping the Id column as it has no use

# %%
iris.drop(['Id'],axis=1,inplace=True)

# %%
iris.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
## Let's check the Relationship Between Columns

# %%
sns.pairplot(iris, hue='Species')

# %% [markdown]
# ### Splitting the dataset

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

X = iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
y = iris['Species'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=17)
 
clf = DecisionTreeClassifier(random_state=17)
clf = clf.fit(X_train, y_train)
 
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
print('\nAccuracy: {0:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       0.96      0.93      0.94        27
#  Iris-virginica       0.89      0.94      0.92        18
#
#        accuracy                           0.95        60
#       macro avg       0.95      0.96      0.95        60
#    weighted avg       0.95      0.95      0.95        60
#
#
# Accuracy: 0.9500

# %% [markdown]
# ### Visualize Decision Tree

# %%
from IPython.display import Image  
from sklearn import tree
import pydotplus

# %%
tree.plot_tree(clf);

# %% [markdown]
# ### Visualize Decision Tree with graphviz

# %%
dot = tree.export_graphviz(clf, out_file=None, feature_names=fn, class_names=cn, filled=True, rounded=True, special_characters=True)
 
graph = graphviz.Source(dot)
graph
